# %%
#FAGSDFASDFASDF
import pandas as pd

# !kaggle datasets download -d paalfer96/energy-demand-in-spain
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paalfer96/energy-demand-in-spain
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/7.02M [00:00<?, ?B/s]
# 100%|██████████| 7.02M/7.02M [00:00<00:00, 1.17GB/s]

# %%
import zipfile

with zipfile.ZipFile("energy-demand-in-spain.zip", 'r') as zip_ref:
    zip_ref.extractall("energy-data")

# %%
import os
# Muestra la ruta absoluta actual
print(os.getcwd())
# Out:
# c:\Users\sergi\AppData\Local\Programs\Microsoft VS Code

# %%
# Lista todos los archivos y subcarpetas dentro de "energy-data"
os.listdir("energy-data")
# Out:
# ['Demand_data.csv']

# %%
df = pd.read_csv("energy-data/Demand_data.csv")
df.info()
print(df.head())
print(df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918788 entries, 0 to 918787
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Hora        918788 non-null  object
#  1   Real        893596 non-null  float64
#  2   Prevista    917290 non-null  float64
#  3   Programada  918636 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 28.0+ MB
#                Hora    Real  Prevista  Programada
# 0  2006-12-31 21:00  27.611    32.407      29.934
# 1  2006-12-31 21:10  27.355    32.301      29.934
# 2  2006-12-31 21:20  27.166    31.995      29.934
# 3  2006-12-31 21:30  26.848    31.489      29.934
# 4  2006-12-31 21:40  26.485    30.782      29.934
#                     Hora  Real  Prevista  Programada
# 918783  2020-07-11 03:10   NaN    23.826      23.642
# 918784  2020-07-11 03:20   NaN    23.710      23.642
# 918785  2020-07-11 03:30   NaN    23.599      23.642
# ...

# %% [markdown]
# Hasta el momento lo que he realizado es preparar el espacio de trabajo, actualizar python, instalar la API de Kaggle y descargar el archivo CSV para poder visualizar los datos del consumo energético en España.
# Justo en la ultima linea de código ejecutada lo que hago es usar pandas para crear un DataFrame llamado df.
# luego pido la información del archivo, para conocer los tipos de datos que tengo, si hay datos ausentes (NaN o None)
# y por ultimo quiero que me muestre las primeros y las ultimas 5 filas que tengo en mi documento.
#
# A CONTINUACIÓN:
# puedo convertir la columna "Hora" a formato Datetime con pd.to_datetime()
